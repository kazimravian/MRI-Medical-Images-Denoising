# %%
import tensorflow as tf
from tensorflow.keras.layers import InputLayer
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.activations import relu
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# load MR images dataset
import pickle
mri_file = open("/content/drive/MyDrive/MRI-Medical-Images-Denoising/mri_dataset/mri_imgs.pickle", 'rb')
mri_imgs= pickle.load(mri_file)
print(type(mri_imgs))
print(mri_imgs.shape)
# Out:
# <class 'numpy.ndarray'>
# (7087, 128, 128, 3)

# %%
# split train and test images
from sklearn.model_selection import train_test_split
x_train, x_test = train_test_split(mri_imgs, test_size = 0.2, train_size = 0.8, shuffle = True, random_state = 0)

# %%
# shape of train and test images
print(x_train.shape)
print(x_test.shape)
# Out:
# (5669, 128, 128, 3)
# (1418, 128, 128, 3)

# %%
# convert float types and normalize mri images
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

print(x_train.dtype)
print(x_test.dtype)
# Out:
# float32
# float32

# %%
# reshape into tensor
#x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 3)
#x_test = x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 3)
print(x_train.shape)
print(x_test.shape)
# Out:
# (5669, 128, 128, 3)
# (1418, 128, 128, 3)

# %%
# show some training mri images
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  plt.imshow(x_train[idx])

# %%
# show some testing mri images
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  plt.imshow(x_test[idx])

# %% [markdown]
# # Add Gassian Noise in images

# %%
from skimage.util import random_noise

# %%
g_noise_x_train = random_noise(x_train, mode = 'gaussian', mean = 0, var = 0.2)
g_noise_x_test = random_noise(x_test, mode = 'gaussian', mean = 0, var = 0.2)

# %%
# show some noisy mri images
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  plt.imshow(g_noise_x_train[idx])

# %%
# show some restored images
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  plt.imshow(g_noise_x_test[idx])

# %%
# define encoder
inputs = layers.Input(shape = [128, 128, 3])
x = inputs

c1 = Conv2D(filters = 32, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(x)
c1 = Conv2D(filters = 32, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(c1)
c1 = Conv2D(filters = 32, kernel_size = (3, 3), strides = 2, padding = 'same', activation = relu)(c1)
c1 = tf.keras.layers.Dropout(0.2)(c1)
  
c2 = Conv2D(filters = 64, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(c1)
c2 = Conv2D(filters = 64, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(c2)
c2 = Conv2D(filters = 64, kernel_size = (3, 3), strides = 2, padding = 'same', activation = relu)(c2)
c2 = tf.keras.layers.Dropout(0.2)(c2)

c3 = Conv2D(filters = 128, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(c2)
c3 = Conv2D(filters = 128, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(c3)
c3 = Conv2D(filters = 128, kernel_size = (3, 3), strides = 2, padding = 'same', activation = relu)(c3)
c3 = tf.keras.layers.Dropout(0.2)(c3)

c4 = Conv2D(filters = 256, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(c3)
c4 = Conv2D(filters = 256, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(c4)
c4 = Conv2D(filters = 256, kernel_size = (3, 3), strides = 2, padding = 'same', activation = relu)(c4)
c4 = tf.keras.layers.Dropout(0.2)(c4)

c5 = Conv2D(filters = 512, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(c4)
c5 = Conv2D(filters = 512, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(c5)
c5 = Conv2D(filters = 512, kernel_size = (3, 3), strides = 2, padding = 'same', activation = relu)(c5)
c5 = tf.keras.layers.Dropout(0.2)(c5)

c6 = Conv2D(filters = 1024, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(c5)
c6 = Conv2D(filters = 1024, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(c6)
c6 = Conv2D(filters = 1024, kernel_size = (3, 3), strides = 2, padding = 'same', activation = relu)(c6)
c6 = tf.keras.layers.Dropout(0.2)(c6)

# define decoder
u1 = Conv2DTranspose(filters = 512, kernel_size = (3, 3), strides = 2, padding = 'same', activation = relu)(c6)
u1 = tf.keras.layers.add([u1, c5])
u1 = concatenate([u1, c5])
u1 = Conv2D(filters = 1024, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u1)
u1 = Conv2D(filters = 1024, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u1)
u1 = Conv2D(filters = 1024, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u1)
u1 = tf.keras.layers.Dropout(0.2)(u1)

u2 = Conv2DTranspose(filters = 256, kernel_size = (3, 3), strides = 2, padding = 'same', activation = relu)(u1)
u2 = tf.keras.layers.add([u2, c4])
u2 = concatenate([u2, c4])
u2 = Conv2D(filters = 512, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u2)
u2 = Conv2D(filters = 512, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u2)
u2 = Conv2D(filters = 512, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u2)
u2 = tf.keras.layers.Dropout(0.2)(u2)

u3 = Conv2DTranspose(filters = 128, kernel_size = (3, 3), strides = 2, padding = 'same', activation = relu)(u2)
u3 = tf.keras.layers.add([u3, c3])
u3 = concatenate([u3, c3])
u3 = Conv2D(filters = 256, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u3)
u3 = Conv2D(filters = 256, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u3)
u3 = Conv2D(filters = 256, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u3)
u3 = tf.keras.layers.Dropout(0.2)(u3)

u4 = Conv2DTranspose(filters = 64, kernel_size = (3, 3), strides = 2, padding = 'same', activation = relu)(u3)
u4 = tf.keras.layers.add([u4, c2])
u4 = concatenate([u4, c2])
u4 = Conv2D(filters = 128, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u4)
u4 = Conv2D(filters = 128, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u4)
u4 = Conv2D(filters = 128, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u4)
u4 = tf.keras.layers.Dropout(0.2)(u4)

u5 = Conv2DTranspose(filters = 32, kernel_size = (3, 3), strides = 2, padding = 'same', activation = relu)(u4)
u5 = tf.keras.layers.add([u5, c1])
u5 = concatenate([u5, c1])
u5 = Conv2D(filters = 64, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u5)
u5 = Conv2D(filters = 64, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u5)
u5 = Conv2D(filters = 64, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u5)
u5 = tf.keras.layers.Dropout(0.2)(u5)

u6 = Conv2DTranspose(filters = 1, kernel_size = (3, 3), strides = 2, padding = 'same', activation = relu)(u5)
u6 = tf.keras.layers.add([u6, x])
u6 = concatenate([u6, x])
u6 = Conv2D(filters = 32, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u6)
u6 = Conv2D(filters = 32, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u6)
u6 = Conv2D(filters = 32, kernel_size = (3, 3), strides = 1, padding = 'same', activation = relu)(u6)
u6 = tf.keras.layers.Dropout(0.2)(u6)

out = Conv2D(filters = 3, kernel_size = (3, 3), strides = 1, padding = 'same', activation = 'sigmoid')(u6)
out = tf.keras.layers.add([tf.constant(0.003)*inputs, out])

model = Model(inputs = inputs, outputs = out, name = 'Eecoder-Decoder')
model.summary()
# Out:
# Model: "Eecoder-Decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   9248        ['conv2d_1[0][0]']
#
#  dropout (Dropout)              (None, 64, 64, 32)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   18496       ['dropout[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 64)   36928       ['conv2d_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 128)  73856       ['dropout_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 128)  147584      ['conv2d_7[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 256)  295168      ['dropout_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 256)  590080      ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 256)    590080      ['conv2d_10[0][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 256)    0           ['conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 512)    1180160     ['dropout_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 512)    2359808     ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 4, 4, 512)    2359808     ['conv2d_13[0][0]']
#
#  dropout_4 (Dropout)            (None, 4, 4, 512)    0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 4, 4, 1024)   4719616     ['dropout_4[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 4, 4, 1024)   9438208     ['conv2d_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 2, 2, 1024)   9438208     ['conv2d_16[0][0]']
#
#  dropout_5 (Dropout)            (None, 2, 2, 1024)   0           ['conv2d_17[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 4, 4, 512)   4719104     ['dropout_5[0][0]']
#  ose)
#
#  add (Add)                      (None, 4, 4, 512)    0           ['conv2d_transpose[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  concatenate (Concatenate)      (None, 4, 4, 1024)   0           ['add[0][0]',
#                                                                   'dropout_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 4, 4, 1024)   9438208     ['concatenate[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 4, 4, 1024)   9438208     ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 4, 4, 1024)   9438208     ['conv2d_19[0][0]']
#
#  dropout_6 (Dropout)            (None, 4, 4, 1024)   0           ['conv2d_20[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 8, 8, 256)   2359552     ['dropout_6[0][0]']
#  spose)
#
#  add_1 (Add)                    (None, 8, 8, 256)    0           ['conv2d_transpose_1[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 512)    0           ['add_1[0][0]',
#                                                                   'dropout_3[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 8, 8, 512)    2359808     ['concatenate_1[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 512)    2359808     ['conv2d_21[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 8, 8, 512)    2359808     ['conv2d_22[0][0]']
#
#  dropout_7 (Dropout)            (None, 8, 8, 512)    0           ['conv2d_23[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 16, 16, 128)  589952     ['dropout_7[0][0]']
#  spose)
#
#  add_2 (Add)                    (None, 16, 16, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 16, 16, 256)  0           ['add_2[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 256)  590080      ['concatenate_2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 256)  590080      ['conv2d_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 256)  590080      ['conv2d_25[0][0]']
#
#  dropout_8 (Dropout)            (None, 16, 16, 256)  0           ['conv2d_26[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 32, 32, 64)  147520      ['dropout_8[0][0]']
#  spose)
#
#  add_3 (Add)                    (None, 32, 32, 64)   0           ['conv2d_transpose_3[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 128)  0           ['add_3[0][0]',
#                                                                   'dropout_1[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 128)  147584      ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 128)  147584      ['conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 128)  147584      ['conv2d_28[0][0]']
#
#  dropout_9 (Dropout)            (None, 32, 32, 128)  0           ['conv2d_29[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 32)  36896       ['dropout_9[0][0]']
#  spose)
#
#  add_4 (Add)                    (None, 64, 64, 32)   0           ['conv2d_transpose_4[0][0]',
#                                                                   'dropout[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 64)   0           ['add_4[0][0]',
#                                                                   'dropout[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 64)   36928       ['concatenate_4[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 64)   36928       ['conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 64)   36928       ['conv2d_31[0][0]']
#
#  dropout_10 (Dropout)           (None, 64, 64, 64)   0           ['conv2d_32[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 1)  577        ['dropout_10[0][0]']
#  spose)
#
#  add_5 (Add)                    (None, 128, 128, 3)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'input_1[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 6)  0           ['add_5[0][0]',
#                                                                   'input_1[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 32  1760        ['concatenate_5[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 32  9248        ['conv2d_33[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 128, 128, 32  9248        ['conv2d_34[0][0]']
#                                 )
#
#  dropout_11 (Dropout)           (None, 128, 128, 32  0           ['conv2d_35[0][0]']
#                                 )
#
#  tf.math.multiply (TFOpLambda)  (None, 128, 128, 3)  0           ['input_1[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 128, 128, 3)  867         ['dropout_11[0][0]']
#
#  add_6 (Add)                    (None, 128, 128, 3)  0           ['tf.math.multiply[0][0]',
#                                                                   'conv2d_36[0][0]']
#
# ==================================================================================================
# Total params: 77,044,452
# Trainable params: 77,044,452
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_path = '/content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5'
checkpoint = ModelCheckpoint(model_path, 
                             monitor= "val_loss", 
                             verbose=1, 
                             save_best_only=True, 
                             mode= "auto", 
                             save_weights_only = False)

early = EarlyStopping(monitor= "val_loss", 
                      mode= "auto", 
                      patience = 20)

callbacks_list = [checkpoint, early]

# %%
model.compile(optimizer = 'adam', loss = 'mse')

# %%
model.fit(g_noise_x_train, x_train,
                      validation_data = (g_noise_x_test, x_test),
                      epochs = 100, batch_size = 50, callbacks = callbacks_list)
# Out:
# Epoch 1/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0270
# Epoch 1: val_loss improved from inf to 0.01045, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 134s 1s/step - loss: 0.0270 - val_loss: 0.0105
# Epoch 2/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0102
# Epoch 2: val_loss improved from 0.01045 to 0.00900, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0102 - val_loss: 0.0090
# Epoch 3/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 3: val_loss improved from 0.00900 to 0.00809, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0090 - val_loss: 0.0081
# Epoch 4/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0083
# Epoch 4: val_loss improved from 0.00809 to 0.00760, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0083 - val_loss: 0.0076
# Epoch 5/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 5: val_loss improved from 0.00760 to 0.00710, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0078 - val_loss: 0.0071
# Epoch 6/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 6: val_loss improved from 0.00710 to 0.00707, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0076 - val_loss: 0.0071
# Epoch 7/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 7: val_loss improved from 0.00707 to 0.00657, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0071 - val_loss: 0.0066
# Epoch 8/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 8: val_loss improved from 0.00657 to 0.00629, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0068 - val_loss: 0.0063
# Epoch 9/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 9: val_loss improved from 0.00629 to 0.00602, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0066 - val_loss: 0.0060
# Epoch 10/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 10: val_loss improved from 0.00602 to 0.00578, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 11/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 11: val_loss did not improve from 0.00578
# 114/114 [==============================] - 108s 944ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 12/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 12: val_loss did not improve from 0.00578
# 114/114 [==============================] - 107s 943ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 13/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0060
# Epoch 13: val_loss improved from 0.00578 to 0.00559, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 14/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 14: val_loss improved from 0.00559 to 0.00550, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 119s 1s/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 15/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 15: val_loss improved from 0.00550 to 0.00535, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0058 - val_loss: 0.0054
# Epoch 16/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 16: val_loss did not improve from 0.00535
# 114/114 [==============================] - 108s 943ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 17/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 17: val_loss improved from 0.00535 to 0.00517, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 18/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 18: val_loss did not improve from 0.00517
# 114/114 [==============================] - 108s 945ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 19/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 19: val_loss did not improve from 0.00517
# 114/114 [==============================] - 107s 943ms/step - loss: 0.0056 - val_loss: 0.0053
# Epoch 20/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 20: val_loss improved from 0.00517 to 0.00509, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0055 - val_loss: 0.0051
# Epoch 21/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0055
# Epoch 21: val_loss improved from 0.00509 to 0.00501, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0055 - val_loss: 0.0050
# Epoch 22/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 22: val_loss improved from 0.00501 to 0.00493, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 23/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 23: val_loss did not improve from 0.00493
# 114/114 [==============================] - 108s 943ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 24/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 24: val_loss did not improve from 0.00493
# 114/114 [==============================] - 107s 943ms/step - loss: 0.0053 - val_loss: 0.0056
# Epoch 25/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 25: val_loss improved from 0.00493 to 0.00490, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 26/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 26: val_loss did not improve from 0.00490
# 114/114 [==============================] - 108s 943ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 27/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 27: val_loss improved from 0.00490 to 0.00485, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0053 - val_loss: 0.0048
# Epoch 28/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 28: val_loss improved from 0.00485 to 0.00479, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 29/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0052
# Epoch 29: val_loss did not improve from 0.00479
# 114/114 [==============================] - 108s 944ms/step - loss: 0.0052 - val_loss: 0.0048
# Epoch 30/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 30: val_loss did not improve from 0.00479
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 31/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 31: val_loss did not improve from 0.00479
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0051 - val_loss: 0.0054
# Epoch 32/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 32: val_loss improved from 0.00479 to 0.00473, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 33/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 33: val_loss improved from 0.00473 to 0.00470, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0050 - val_loss: 0.0047
# Epoch 34/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0051
# Epoch 34: val_loss did not improve from 0.00470
# 114/114 [==============================] - 107s 943ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 35/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 35: val_loss improved from 0.00470 to 0.00464, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0050 - val_loss: 0.0046
# Epoch 36/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 36: val_loss did not improve from 0.00464
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 37/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 37: val_loss did not improve from 0.00464
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 38/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 38: val_loss improved from 0.00464 to 0.00459, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 39/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 39: val_loss did not improve from 0.00459
# 114/114 [==============================] - 107s 943ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 40/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 40: val_loss did not improve from 0.00459
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 41/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0049
# Epoch 41: val_loss improved from 0.00459 to 0.00455, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 42/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 42: val_loss did not improve from 0.00455
# 114/114 [==============================] - 108s 943ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 43/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 43: val_loss did not improve from 0.00455
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 44/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 44: val_loss improved from 0.00455 to 0.00455, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 45/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 45: val_loss did not improve from 0.00455
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 46/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 46: val_loss improved from 0.00455 to 0.00449, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0048 - val_loss: 0.0045
# Epoch 47/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 47: val_loss did not improve from 0.00449
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 48/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 48: val_loss did not improve from 0.00449
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 49/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 49: val_loss improved from 0.00449 to 0.00447, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 50/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 50: val_loss did not improve from 0.00447
# 114/114 [==============================] - 107s 943ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 51/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 51: val_loss did not improve from 0.00447
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 52/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 52: val_loss improved from 0.00447 to 0.00446, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 53/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 53: val_loss did not improve from 0.00446
# 114/114 [==============================] - 108s 943ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 54/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 54: val_loss did not improve from 0.00446
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 55/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 55: val_loss improved from 0.00446 to 0.00443, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 56/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 56: val_loss did not improve from 0.00443
# 114/114 [==============================] - 108s 943ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 57/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 57: val_loss improved from 0.00443 to 0.00442, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 58/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0046
# Epoch 58: val_loss did not improve from 0.00442
# 114/114 [==============================] - 108s 943ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 59/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 59: val_loss did not improve from 0.00442
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 60/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 60: val_loss improved from 0.00442 to 0.00441, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 61/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 61: val_loss did not improve from 0.00441
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 62/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 62: val_loss improved from 0.00441 to 0.00439, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 63/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 63: val_loss did not improve from 0.00439
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 64/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 64: val_loss did not improve from 0.00439
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 65/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 65: val_loss did not improve from 0.00439
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 66/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 66: val_loss improved from 0.00439 to 0.00437, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 67/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 67: val_loss did not improve from 0.00437
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 68/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 68: val_loss did not improve from 0.00437
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 69/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 69: val_loss did not improve from 0.00437
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 70/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 70: val_loss did not improve from 0.00437
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 71/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 71: val_loss did not improve from 0.00437
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 72/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 72: val_loss did not improve from 0.00437
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 73/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 73: val_loss improved from 0.00437 to 0.00434, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 117s 1s/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 74/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 74: val_loss did not improve from 0.00434
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 75/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 75: val_loss did not improve from 0.00434
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0043 - val_loss: 0.0045
# Epoch 76/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 76: val_loss improved from 0.00434 to 0.00433, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 77/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 77: val_loss did not improve from 0.00433
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 78/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 78: val_loss did not improve from 0.00433
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 79/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 79: val_loss did not improve from 0.00433
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 80/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 80: val_loss did not improve from 0.00433
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 81/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 81: val_loss did not improve from 0.00433
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 82/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 82: val_loss did not improve from 0.00433
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 83/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0043
# Epoch 83: val_loss did not improve from 0.00433
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 84/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 84: val_loss improved from 0.00433 to 0.00432, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 118s 1s/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 85/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 85: val_loss improved from 0.00432 to 0.00431, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 86/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 86: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 87/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 87: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 88/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 88: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 89/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 89: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 90/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 90: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 91/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 91: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 92/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 92: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 93/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 93: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 940ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 94/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 94: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 95/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 95: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 940ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 96/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 96: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 940ms/step - loss: 0.0042 - val_loss: 0.0045
# Epoch 97/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 97: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0042 - val_loss: 0.0046
# Epoch 98/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 98: val_loss did not improve from 0.00431
# 114/114 [==============================] - 107s 941ms/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 99/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0041
# Epoch 99: val_loss improved from 0.00431 to 0.00428, saving model to /content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5
# 114/114 [==============================] - 116s 1s/step - loss: 0.0041 - val_loss: 0.0043
# Epoch 100/100
# 114/114 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 100: val_loss did not improve from 0.00428
# 114/114 [==============================] - 107s 942ms/step - loss: 0.0042 - val_loss: 0.0043

# %%
val_loss_values = model.history.history['val_loss']
epochs = range(1, len(val_loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values)
plt.setp(line1, linewidth = 2, marker = 's', markersize = 5, color = 'brown')
plt.xlabel('Number of Epochs') 
plt.ylabel('MR Images Restoration Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
model = tf.keras.models.load_model("/content/drive/MyDrive/MRI-Medical-Images-Denoising/Models/gaussian_model.h5")

# %%
output_images = model.predict(g_noise_x_test)

# %%
# show some restored images
fig = plt.figure(figsize = (20, 4))

for idx in range(20):
  ax = fig.add_subplot(2, 10, idx + 1, xticks = [], yticks = [])
  plt.imshow(np.clip(output_images[idx], 0, 1))

# %%
psnr = tf.image.psnr(output_images, x_test, max_val = 255)
psnr.numpy().mean()
# Out:
# 72.63193

# %%
ssim = tf.image.ssim(output_images, x_test, 1, filter_size = 11, filter_sigma = 1.5, k1 = 0.01, k2 = 0.03)
round(ssim.numpy().mean(), 4)
# Out:
# 0.7382

# %%
# display the 1st 8 test input and decoded images

imgs = np.concatenate([x_test[:10], g_noise_x_test[:10], output_images[:10]])
imgs = imgs.reshape((3, 10, 128, 128, 3))

imgs = np.vstack([np.hstack(i) for i in imgs])
plt.figure(figsize = (24, 6))
plt.axis('off')
plt.title('Frist row shows original images, 2nd row shows images with gaussian noise, 3rd row shows denoising images by the proposed method')
plt.imshow(imgs, interpolation='none', cmap = 'gray')
